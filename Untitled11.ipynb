# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

file_path = r"C:\Users\elaki\Downloads\Fashion(Data Points) - Form responses 1 (1).csv"
df = pd.read_csv(file_path, low_memory=False)

print(df.head())
# Out:
#              Timestamp   1.Age Group     2.Gender     3.Profession    \
# 0  14/01/2025 19:33:18           18–24       Female          Student
# 1  21/01/2025 22:13:55           18–24       Female          Student
# 2  21/01/2025 22:24:31           18–24       Female          Student
# 3  21/01/2025 22:25:53           18–24         Male          Student
# 4  21/01/2025 22:38:46           18–24         Male          Student
#
#   Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)    \
# 0                     Chic (e.g., tailored, stylish)
# 1                     Casual (e.g., jeans, t-shirts)
# 2                     Casual (e.g., jeans, t-shirts)
# 3                     Casual (e.g., jeans, t-shirts)
# 4                     Casual (e.g., jeans, t-shirts)
#
#    5. What’s your favorite color palette for clothing?    \
# 0                     Pastels (soft pink, baby blue)
# 1                          Dark tones (navy, maroon)
# ...

# %%
result = df.iloc[:5, :5]
print(result)
# Out:
#              Timestamp   1.Age Group     2.Gender     3.Profession    \
# 0  14/01/2025 19:33:18           18–24       Female          Student
# 1  21/01/2025 22:13:55           18–24       Female          Student
# 2  21/01/2025 22:24:31           18–24       Female          Student
# 3  21/01/2025 22:25:53           18–24         Male          Student
# 4  21/01/2025 22:38:46           18–24         Male          Student
#
#   Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)
# 0                     Chic (e.g., tailored, stylish)
# 1                     Casual (e.g., jeans, t-shirts)
# 2                     Casual (e.g., jeans, t-shirts)
# 3                     Casual (e.g., jeans, t-shirts)
# 4                     Casual (e.g., jeans, t-shirts)

# %%
df
# Out:
#                Timestamp   1.Age Group     2.Gender     3.Profession    \
# 0    14/01/2025 19:33:18           18–24       Female          Student
# 1    21/01/2025 22:13:55           18–24       Female          Student
# 2    21/01/2025 22:24:31           18–24       Female          Student
# 3    21/01/2025 22:25:53           18–24         Male          Student
# 4    21/01/2025 22:38:46           18–24         Male          Student
# ..                   ...             ...          ...              ...
# 145  31/01/2025 18:01:08           18–24         Male          Student
# 146  31/01/2025 18:30:24           18–24         Male          Student
# 147  03/02/2025 23:34:39           18–24         Male          Student
# 148  04/02/2025 00:03:43           18–24         Male          Student
# 149  17/02/2025 22:08:18           18–24         Male          Student
#
#     Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)    \
# ...

# %%
df.shape
# Out:
# (150, 20)

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                            0
#   1.Age Group                                                                                        0
#   2.Gender                                                                                           0
#   3.Profession                                                                                       0
# Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)        1
#  5. What’s your favorite color palette for clothing?                                                 0
#  6. Do you prioritize functionality or aesthetics in your outfits?                                   1
#   7.Which of these best describes your wardrobe?                                                     2
# Section 3: Shopping Habits\n8. How often do you shop for new clothes?                                1
# ...

# %%
df
# Out:
#                Timestamp   1.Age Group     2.Gender     3.Profession    \
# 0    14/01/2025 19:33:18           18–24       Female          Student
# 1    21/01/2025 22:13:55           18–24       Female          Student
# 2    21/01/2025 22:24:31           18–24       Female          Student
# 3    21/01/2025 22:25:53           18–24         Male          Student
# 4    21/01/2025 22:38:46           18–24         Male          Student
# ..                   ...             ...          ...              ...
# 145  31/01/2025 18:01:08           18–24         Male          Student
# 146  31/01/2025 18:30:24           18–24         Male          Student
# 147  03/02/2025 23:34:39           18–24         Male          Student
# 148  04/02/2025 00:03:43           18–24         Male          Student
# 149  17/02/2025 22:08:18           18–24         Male          Student
#
#     Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)    \
# ...

# %%
df.columns = df.columns.str.strip()

# %%
cleaned_df = df.iloc[:5, :5]

# %%
print(cleaned_df)
# Out:
#              Timestamp 1.Age Group 2.Gender 3.Profession  \
# 0  14/01/2025 19:33:18       18–24   Female      Student
# 1  21/01/2025 22:13:55       18–24   Female      Student
# 2  21/01/2025 22:24:31       18–24   Female      Student
# 3  21/01/2025 22:25:53       18–24     Male      Student
# 4  21/01/2025 22:38:46       18–24     Male      Student
#
#   Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)
# 0                     Chic (e.g., tailored, stylish)
# 1                     Casual (e.g., jeans, t-shirts)
# 2                     Casual (e.g., jeans, t-shirts)
# 3                     Casual (e.g., jeans, t-shirts)
# 4                     Casual (e.g., jeans, t-shirts)

# %%
df
# Out:
#                Timestamp 1.Age Group 2.Gender 3.Profession  \
# 0    14/01/2025 19:33:18       18–24   Female      Student
# 1    21/01/2025 22:13:55       18–24   Female      Student
# 2    21/01/2025 22:24:31       18–24   Female      Student
# 3    21/01/2025 22:25:53       18–24     Male      Student
# 4    21/01/2025 22:38:46       18–24     Male      Student
# ..                   ...         ...      ...          ...
# 145  31/01/2025 18:01:08       18–24     Male      Student
# 146  31/01/2025 18:30:24       18–24     Male      Student
# 147  03/02/2025 23:34:39       18–24     Male      Student
# 148  04/02/2025 00:03:43       18–24     Male      Student
# 149  17/02/2025 22:08:18       18–24     Male      Student
#
#     Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)  \
# 0                       Chic (e.g., tailored, stylish)
# 1                       Casual (e.g., jeans, t-shirts)
# ...

# %%
seaborn.pairplot(df[['Age Group']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 seaborn.pairplot(df[['Age Group']])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
KeyError: "None of [Index(['Age Group'], dtype='object')] are in the [columns]"

# %%
x = df.drop(['Timestamp'],axis =1)
x
# Out:
#     1.Age Group 2.Gender 3.Profession  \
# 0         18–24   Female      Student
# 1         18–24   Female      Student
# 2         18–24   Female      Student
# 3         18–24     Male      Student
# 4         18–24     Male      Student
# ..          ...      ...          ...
# 145       18–24     Male      Student
# 146       18–24     Male      Student
# 147       18–24     Male      Student
# 148       18–24     Male      Student
# 149       18–24     Male      Student
#
#     Section 2: Style Preferences\n4. How would you describe your go-to daily outfit? (Select one)  \
# 0                       Chic (e.g., tailored, stylish)
# 1                       Casual (e.g., jeans, t-shirts)
# 2                       Casual (e.g., jeans, t-shirts)
# 3                       Casual (e.g., jeans, t-shirts)
# 4                       Casual (e.g., jeans, t-shirts)
# ..                                                 ...
# 145                      Formal (e.g., suits, dresses)
# ...

# %% [markdown]
# # Assistant
# This error occurs because the DataFrame `df` doesn't have columns named 'Age group' and 'Gender'. The `drop()` function is trying to remove columns that don't exist in the DataFrame.
#
# Would you like me to provide the corrected code?

# %%
y = df['Column 18']
y
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 145   NaN
# 146   NaN
# 147   NaN
# 148   NaN
# 149   NaN
# Name: Column 18, Length: 150, dtype: float64

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to access a column named 'Gender' in a DataFrame (df), but this column doesn't exist in the DataFrame.
#
# The KeyError indicates that 'Gender' is not a valid key (column name) in your DataFrame. This could be due to:
#
# 1. A typo in the column name (case sensitivity matters)
# 2. The column might have a different name
# 3. The column might not exist at all in your DataFrame
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to access a column named 'Gender' in a DataFrame (df), but this column doesn't exist in the DataFrame.
#
# The KeyError indicates that 'Gender' is not a valid key (column name) in your DataFrame. This could be due to:
#
# 1. A typo in the column name (case sensitivity matters)
# 2. The column might have a different name
# 3. The column might not exist at all in your DataFrame
#
# Would you like me to provide the corrected code?

# %%
import sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters = 5) # k = 5

# %%
kmeans = kmeans.fit(df['Do you prioritize functionality or aesthetics in your outfits?])
# Out:
#   Cell In[37], line 1
#     kmeans = kmeans.fit(df['Do you prioritize functionality or aesthetics in your outfits?])
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Assistant
# The error occurs because there's an issue with the string quotes in your code. You have unbalanced square brackets and quotes.
#
# In your code:

# %%
kmeans = kmeans.fit(df['Do you prioritize functionality or aesthetics in your outfits?'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Do you prioritize functionality or aesthetics in your outfits?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ...

# %% [markdown]
# The problem is that you have three opening square brackets `[[[` but only two closing ones `]]`. This creates an unterminated string literal.
#
# Would you like me to provide the corrected code?

# %%
df['clusters'] = kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['clusters'] = kmeans.labels_
#
# AttributeError: 'KMeans' object has no attribute 'labels_'
